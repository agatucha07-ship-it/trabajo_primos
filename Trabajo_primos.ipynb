# %% [markdown]
# <a href="https://colab.research.google.com/github/agatucha07-ship-it/trabajo_primos/blob/main/Trabajo_primos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# codigo para verificacion de numeros primos

numero = int(input("Leer número: "))

if numero <= 1:
    print("No es primo")
else:
# Out:
#   File "/tmp/ipython-input-746349083.py", line 4
#     elif numero == 2 or numero == 3:
#     ^
# SyntaxError: invalid syntax

# %%
# codigo para verificacion de numeros primos

número = int(input("LEER número: "))
# todo los numeros enteros
if numero <= 1:
    print("No es primo")
# solo numeros naturales
else:
    if numero == 2 or numero == 3:
        print("Es primo")
# son primos ambos
    else:
        if numero % 2 == 0 or numero % 3 == 0:
            print("No es primo")
# % (mod) resultado de la division
        else:
            print("Es primo")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1801135005.py in <cell line: 0>()
#       1 # codigo para verificacion de numeros primos
#       2
# ----> 3 número = int(input("LEER número: "))
#       4 # todo los numeros enteros
#       5 if numero <= 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# codigo para verificacion de numeros primos

numero = int(input("LEER número: "))
# todo los numeros enteros
if numero <= 1:
    print("No es primo")
# solo numeros naturales

else:
  if numero % 2 == 0 or numero % 3 == 0:
       print("No es primo")
# % (mod) resultado de la division
  else:
        print("Es primo")
# Out:
# LEER número: 2
# No es primo

# %% [markdown]
# **Trabajo para veridicar numero primo**

# %%
# codigo para verificacion de numeros primos

numero = int(input("LEER número: "))
# todo los numeros enteros
if numero <= 1:
    print("No es primo")
# solo numeros naturales
else:
    if numero == 2 or numero == 3:
        print("Es primo")
# son primos ambos
    else:
        if numero % 2 == 0 or numero % 3 == 0:
            print("No es primo")
# % (mod) resultado de la division
        else:
            print("Es primo")
# Out:
# LEER número: 80
# No es primo
